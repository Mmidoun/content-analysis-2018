# %%
#Special module written for this class
#This provides access to data and to helper functions from previous weeks
import lucem_illud #pip install git+git://github.com/Computational-Content-Analysis-2018/lucem_illud.git

#All these packages need to be installed from pip
import requests #for http requests
import bs4 #called `beautifulsoup4`, an html parser
import pandas #gives us DataFrames
import docx #reading MS doc files, install as `python-docx`

#Stuff for pdfs
#Install as `pdfminer2`
import pdfminer.pdfinterp
import pdfminer.converter
import pdfminer.layout
import pdfminer.pdfpage

#These come with Python
import re #for regexs
import urllib.parse #For joining urls
import io #for making http requests look like files
import json #For Tumblr API responses
import os.path #For checking if files exist
import os #For making directories

# %%
#wikipedia_base_url = 'https://en.wikipedia.org'
#wikipedia_women_in_medicine = 'https://en.wikipedia.org/wiki/Women_in_medicine'
#women_in_medicine_save = 'wikipedia_women_in_medicine.html'
feminem_base_url = 'https://feminem.org/'
feminem_change = 'https://feminem.org/2018/01/23/being-a-champion-of-change/'
feminem_change_save = 'feminem_change.html'

# %%
#requests.get(wikipedia_women_in_medicine)
requests.get(feminem_change)
# Out:
# <Response [200]>

# %%
#wikiWiMRequest = requests.get(wikipedia_women_in_medicine)
#print(wikiWiMRequest.text[:1000])
feminemchangeRequest = requests.get(feminem_change)
print(feminemchangeRequest.text[:200])
# Out:
# <!DOCTYPE html>
# <!--
# ================================================
# == built by... =================================
# ================================================
#  __    __     ______     __

# %%
feminemchangeSoup = bs4.BeautifulSoup(feminemchangeRequest.text, 'html.parser')
print(feminemchangeSoup.text[:200])
# Out:
# Being a Champion of Change - FemInEM
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {"@context":"http:\/\/schema.org","@type":"WebSite","@id":"#website","url":"https:\/\/feminem.org\/","name":"FemInEM","potentialA

# %%
with open(feminem_change_save, mode='w', encoding='utf-8') as f:
    f.write(feminemchangeRequest.text)

# %%
contentPTags = feminemchangeSoup.body.findAll('p')
for pTag in contentPTags[:3]:
    print(pTag.text)
# Out:
# ESTHER CHOO: I was so honored and excited to be up there on the FIX stage with two men I truly admire and emulate. It was a nice opportunity for me to share my thoughts and experiences about championing change. And it was really great to hear how thoughtful and invested both of you are in addressing gender disparities in the healthcare workforce.
# I’d love to hear from you two how you felt our panel went! How was that experience being up there on that stage?
# MICHAEL GISONDI: I can’t say how honored I was to be invited to FIX and included in the Champions of Change Panel. It was intimidating for me to participate, because gender equity is an issue that I am still learning about – and I am no expert. As a child, I was raised in a household in which I regarded my parents as equals. Throughout school, there were always girls (and later women) that outperformed the boys and who kept me on my game. Then when I arrived in residency, I was among 7 men and 1 women in my intern class. It was there, in medicine, that I first witnessed the inequity of women in my chosen profession. In medicine, I watch my female colleagues erroneously referred to as nurses – despite introductions, nametags, and white coats that display otherwise. In medicine, my female colleagues will on average earn less money, receive less promotions, and hold less leadership roles. This is despite spending more time mentoring and coaching trainees, and more time caring for patients.

# %%
contentParagraphs = []
for pTag in contentPTags:
    #strings starting with r are raw so their \'s are not modifier characters
    #If we didn't start with r the string would be: '\\[\\d+\\]'
    contentParagraphs.append(re.sub(r'\[\d+\]', '', pTag.text))

#convert to a DataFrame
contentParagraphsDF = pandas.DataFrame({'paragraph-text' : contentParagraphs})
print(contentParagraphsDF)
# Out:
#                                        paragraph-text
# 0   ESTHER CHOO: I was so honored and excited to b...
# 1   I’d love to hear from you two how you felt our...
# 2   MICHAEL GISONDI: I can’t say how honored I was...
# 3   ADAM BROWN: First, I was so honored to be a pa...
# 4   For me, there was dissonance in gender roles s...
# 5   And suddenly there I was, on a stage, in New Y...
# 6   EC: What did you think the ‘big messages’ from...
# 7   MG: The ‘big messages’ from our session were s...
# 8   AB: I wanted to share the experience of realiz...
# 9   EC: For me, the big walk away was that there *...
# 10                   Watch the full FIX17 talk below!
# 11
# 12
# 13  \r\n                        Be the First to Co...
# 14  Sign up to get the monthly digest, access to a...
# 15  We can't connect with FemInEMs that don't conn...
# 16                                \nEmail Address\n\n
# 17                                   \nFirst Name\n\n
# 18                                    \nLast Name\n\n
# 19  By submitting this form, you are granting http...
# 20  Sign up to get the monthly digest, access to a...
# 21  We can't connect with FemInEMs that don't conn...
# 22                                \nEmail Address\n\n
# 23                                   \nFirst Name\n\n
# 24                                    \nLast Name\n\n
# 25  By submitting this form, you are granting http...

# %%
findNumber = r'\d'
regexResults = re.search(findNumber, 'not a number, not a number, numbers 2134567890, not a number')
regexResults
# Out:
# <_sre.SRE_Match object; span=(36, 37), match='2'>

# %%
print(regexResults.group(0))
# Out:
# 2

# %%
findNumbers = r'\d+'
regexResults = re.search(findNumbers, 'not a number, not a number, numbers 2134567890, not a number')
print(regexResults.group(0))
# Out:
# 2134567890

# %%
otherPAgeURLS = []
for paragraphNum, pTag in enumerate(contentPTags):
    tagLinks = pTag.findAll('a', href=re.compile('/#/'), class_=False)
    for aTag in tagLinks:
        relurl = aTag.get('href')
        linkText = aTag.text
        otherPAgeURLS.append((
            urllib.parse.urljoin(feminem_base_url, relurl),
            paragraphNum,
            linkText,
        ))
print(otherPAgeURLS[:10])
# Out:
# []

# %%
wikipedia_base_url = 'https://en.wikipedia.org'
wikipedia_women_in_medicine = 'https://en.wikipedia.org/wiki/Women_in_medicine'
women_in_medicine_save = 'wikipedia_women_in_medicine.html'

# %%
requests.get(wikipedia_women_in_medicine)
# Out:
# <Response [200]>

# %%
wikiWiMRequest = requests.get(wikipedia_women_in_medicine)
print(wikiWiMRequest.text[:200])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Women in medicine - Wikipedia</title>
# <script>document.documentElement.className = document.documen

# %%
wikiWiMSoup = bs4.BeautifulSoup(wikiWiMRequest.text, 'html.parser')
print(wikiWiMSoup.text[:200])
# Out:
# Women in medicine - Wikipedia
# document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
# (window.RLQ=window.RLQ||[]).push(functi

# %%
with open(women_in_medicine_save, mode='w', encoding='utf-8') as f:
    f.write(wikiWiMRequest.text)

# %%
contentPTags = wikiWiMSoup.body.findAll('p')
for pTag in contentPTags[:3]:
    print(pTag.text)
# Out:
# Historically and presently, in many parts of the world, women's participation in the profession of medicine (as physicians or surgeons for instance) has been significantly restricted. However, women's informal practice of medicine in roles such as caregivers or as allied health professionals has been widespread. Most countries of the world now provide women with equal access to medical education. However, not all countries ensure equal employment opportunities,[1] and gender equality has yet to be achieved within medical specialties and around the world,[2] despite studies suggest that female doctors may be providing higher-quality care than male doctors.[3][4]

# %%
contentParagraphs = []
for pTag in contentPTags:
    #strings starting with r are raw so their \'s are not modifier characters
    #If we didn't start with r the string would be: '\\[\\d+\\]'
    contentParagraphs.append(re.sub(r'\[\d+\]', '', pTag.text))

#convert to a DataFrame
contentParagraphsDF = pandas.DataFrame({'paragraph-text' : contentParagraphs})
print(contentParagraphsDF)
# Out:
#                                        paragraph-text
# 0   Historically and presently, in many parts of t...
# 1
# 2
# 3   In 1540, Henry VIII of England granted the cha...
# 4   At the beginning of the twenty-first century i...
# 5   However, the practice of medicine remains disp...
# 6   Moreover, there are skews within the medical p...
# 7   Women continue to dominate in nursing. In 2000...
# 8   Biomedical research and academic medical profe...
# 9   The glass ceiling is used as a metaphor to con...
# 10  One study surveyed physician mothers and their...
# 11  According to this study, one third of physicia...
# 12  This article provided an overview on the histo...
# 13  In an article titled "I'm too used to it”: A l...
# 14  Specifically, this article described how power...
# 15  On the topic of power dynamics, another study ...
# 16  Another study describes sexual harassment as a...
# 17  Women have successfully provided the world wit...
# 18  Helen Brooke Taussig: The First Female Preside...
# 19  Helen Brooke Taussig was born on May 24th, 189...
# 20  Helen Flanders Dunbar: The "Mother" of Holisti...
# 21  Helen Flanders Dunbar was born in Chicago on M...
# 22  As per the documentary “A Midwife’s Tale”, his...
# 23  A shift from women midwifery to male obstetric...
# 24  The involvement of women in the field of medic...
# 25  During the Middle Ages, convents were an impor...
# 26  Women in the Middle Ages participated in many ...
# 27  Dorotea Bucca was another distinguished Italia...
# 28  For the medieval Islamic world, little specifi...
# 29  Traditional Chinese medicine based on the use ...
# 30  Due to the social custom that men and women sh...
# 31  In the early modern era, following the Middle ...
# 32  When women were routinely forbidden from medic...
# 33  The 1970s marked a great increase of women ent...
# 34  Two laws in the United States lifted restricti...
# 35  At the same time, women's ideas about themselv...
# 36  A sharp increase of women in the medical field...
# 37  With higher numbers of women enrolled in medic...
# 38  With women entering the medical field and wome...
# 39
# 40  While scholars in the history of medicine had ...

# %%
contentParagraphsDF['source'] = [wikipedia_women_in_medicine] * len(contentParagraphsDF['paragraph-text'])
contentParagraphsDF['paragraph-number'] = range(len(contentParagraphsDF['paragraph-text']))

contentParagraphsDF
# Out:
#                                        paragraph-text  \
# 0   Historically and presently, in many parts of t...
# 1
# 2
# 3   In 1540, Henry VIII of England granted the cha...
# 4   At the beginning of the twenty-first century i...
# 5   However, the practice of medicine remains disp...
# 6   Moreover, there are skews within the medical p...
# 7   Women continue to dominate in nursing. In 2000...
# 8   Biomedical research and academic medical profe...
# 9   The glass ceiling is used as a metaphor to con...
# 10  One study surveyed physician mothers and their...
# 11  According to this study, one third of physicia...
# 12  This article provided an overview on the histo...
# 13  In an article titled "I'm too used to it”: A l...
# 14  Specifically, this article described how power...
# 15  On the topic of power dynamics, another study ...
# 16  Another study describes sexual harassment as a...
# 17  Women have successfully provided the world wit...
# 18  Helen Brooke Taussig: The First Female Preside...
# 19  Helen Brooke Taussig was born on May 24th, 189...
# 34  https://en.wikipedia.org/wiki/Women_in_medicine                34
# 35  https://en.wikipedia.org/wiki/Women_in_medicine                35
# 36  https://en.wikipedia.org/wiki/Women_in_medicine                36
# 37  https://en.wikipedia.org/wiki/Women_in_medicine                37
# 38  https://en.wikipedia.org/wiki/Women_in_medicine                38
# 39  https://en.wikipedia.org/wiki/Women_in_medicine                39
# 40  https://en.wikipedia.org/wiki/Women_in_medicine                40

# %%
contentParagraphsDF['source-paragraph-number'] = [None] * len(contentParagraphsDF['paragraph-text'])
contentParagraphsDF['source-paragraph-text'] = [None] * len(contentParagraphsDF['paragraph-text'])

def getTextFromWikiPage(targetURL, sourceParNum, sourceText):
    parsDict = {'source' : [], 'paragraph-number' : [], 'paragraph-text' : [], 'source-paragraph-number' : [],  'source-paragraph-text' : []}
    r = requests.get(targetURL)
    soup = bs4.BeautifulSoup(r.text, 'html.parser')
    for parNum, pTag in enumerate(soup.body.findAll('p')):
        parsDict['paragraph-text'].append(re.sub(r'\[\d+\]', '', pTag.text))
        parsDict['paragraph-number'].append(parNum)
        parsDict['source'].append(targetURL)
        parsDict['source-paragraph-number'].append(sourceParNum)
        parsDict['source-paragraph-text'].append(sourceText)
    return pandas.DataFrame(parsDict)

# %%
for urlTuple in otherPAgeURLS[:3]:
    contentParagraphsDF = contentParagraphsDF.append(getTextFromWikiPage(*urlTuple),ignore_index=True)
contentParagraphsDF
# Out:
#                                        paragraph-text  \
# 0   Historically and presently, in many parts of t...
# 1
# 2
# 3   In 1540, Henry VIII of England granted the cha...
# 4   At the beginning of the twenty-first century i...
# 5   However, the practice of medicine remains disp...
# 6   Moreover, there are skews within the medical p...
# 7   Women continue to dominate in nursing. In 2000...
# 8   Biomedical research and academic medical profe...
# 9   The glass ceiling is used as a metaphor to con...
# 10  One study surveyed physician mothers and their...
# 11  According to this study, one third of physicia...
# 12  This article provided an overview on the histo...
# 13  In an article titled "I'm too used to it”: A l...
# 14  Specifically, this article described how power...
# 15  On the topic of power dynamics, another study ...
# 16  Another study describes sexual harassment as a...
# 17  Women have successfully provided the world wit...
# 18  Helen Brooke Taussig: The First Female Preside...
# 19  Helen Brooke Taussig was born on May 24th, 189...
# 20  Helen Flanders Dunbar: The "Mother" of Holisti...
# 21  Helen Flanders Dunbar was born in Chicago on M...
# 22  As per the documentary “A Midwife’s Tale”, his...
# 23  A shift from women midwifery to male obstetric...
# 24  The involvement of women in the field of medic...
# 25  During the Middle Ages, convents were an impor...
# 26  Women in the Middle Ages participated in many ...
# 27  Dorotea Bucca was another distinguished Italia...
# 28  For the medieval Islamic world, little specifi...
# 29  Traditional Chinese medicine based on the use ...
# 30  Due to the social custom that men and women sh...
# 31  In the early modern era, following the Middle ...
# 32  When women were routinely forbidden from medic...
# 33  The 1970s marked a great increase of women ent...
# 34  Two laws in the United States lifted restricti...
# 35  At the same time, women's ideas about themselv...
# 36  A sharp increase of women in the medical field...
# 37  With higher numbers of women enrolled in medic...
# 38  With women entering the medical field and wome...
# 39
# 40  While scholars in the history of medicine had ...
#
#                                              source  paragraph-number  \
# 0   https://en.wikipedia.org/wiki/Women_in_medicine                 0
# 23                    None                  None
# 24                    None                  None
# 25                    None                  None
# 26                    None                  None
# 27                    None                  None
# 28                    None                  None
# 29                    None                  None
# 30                    None                  None
# 31                    None                  None
# 32                    None                  None
# 33                    None                  None
# 34                    None                  None
# 35                    None                  None
# 36                    None                  None
# 37                    None                  None
# 38                    None                  None
# 39                    None                  None
# 40                    None                  None

# %%
otherPAgeURLS = []
for paragraphNum, pTag in enumerate(contentPTags):
    tagLinks = pTag.findAll('a', href=re.compile('/wiki/'), class_=False)
    for aTag in tagLinks:
        relurl = aTag.get('href')
        linkText = aTag.text
        otherPAgeURLS.append((
            urllib.parse.urljoin(wikipedia_base_url, relurl),
            paragraphNum,
            linkText,
        ))
print(otherPAgeURLS[:10])
# Out:
# [('https://en.wikipedia.org/wiki/Physician', 0, 'physicians'), ('https://en.wikipedia.org/wiki/Allied_health_professions', 0, 'allied health professionals'), ('https://en.wikipedia.org/wiki/Medical_education', 0, 'medical education'), ('https://en.wikipedia.org/wiki/Specialty_(medicine)', 0, 'specialties'), ('https://en.wikipedia.org/wiki/Professionalization', 3, 'professionalizing'), ('https://en.wikipedia.org/wiki/Allied_health_professions', 3, 'allied health professions'), ('https://en.wikipedia.org/wiki/Nursing', 3, 'nursing'), ('https://en.wikipedia.org/wiki/Midwifery', 3, 'midwifery'), ('https://en.wikipedia.org/wiki/Medical_education', 3, 'medical education'), ('https://en.wikipedia.org/wiki/National_Institutes_of_Health', 8, 'National Institutes of Health')]

# %%
contentParagraphsDF['source'] = [wikipedia_women_in_medicine] * len(contentParagraphsDF['paragraph-text'])
contentParagraphsDF['paragraph-number'] = range(len(contentParagraphsDF['paragraph-text']))

contentParagraphsDF
# Out:
#                                        paragraph-text  \
# 0   Historically and presently, in many parts of t...
# 1
# 2
# 3   In 1540, Henry VIII of England granted the cha...
# 4   At the beginning of the twenty-first century i...
# 5   However, the practice of medicine remains disp...
# 6   Moreover, there are skews within the medical p...
# 7   Women continue to dominate in nursing. In 2000...
# 8   Biomedical research and academic medical profe...
# 9   The glass ceiling is used as a metaphor to con...
# 10  One study surveyed physician mothers and their...
# 11  According to this study, one third of physicia...
# 12  This article provided an overview on the histo...
# 13  In an article titled "I'm too used to it”: A l...
# 14  Specifically, this article described how power...
# 15  On the topic of power dynamics, another study ...
# 16  Another study describes sexual harassment as a...
# 17  Women have successfully provided the world wit...
# 18  Helen Brooke Taussig: The First Female Preside...
# 19  Helen Brooke Taussig was born on May 24th, 189...
# 20  Helen Flanders Dunbar: The "Mother" of Holisti...
# 21  Helen Flanders Dunbar was born in Chicago on M...
# 22  As per the documentary “A Midwife’s Tale”, his...
# 23  A shift from women midwifery to male obstetric...
# 24  The involvement of women in the field of medic...
# 25  During the Middle Ages, convents were an impor...
# 26  Women in the Middle Ages participated in many ...
# 27  Dorotea Bucca was another distinguished Italia...
# 28  For the medieval Islamic world, little specifi...
# 29  Traditional Chinese medicine based on the use ...
# 30  Due to the social custom that men and women sh...
# 31  In the early modern era, following the Middle ...
# 32  When women were routinely forbidden from medic...
# 5                     None                  None
# 6                     None                  None
# 7                     None                  None
# 8                     None                  None
# 9                     None                  None
# 10                    None                  None
# 11                    None                  None
# 12                    None                  None
# 13                    None                  None
# 14                    None                  None
# 15                    None                  None
# 16                    None                  None
# 17                    None                  None
# 18                    None                  None
# 19                    None                  None
# 20                    None                  None
# 21                    None                  None
# 22                    None                  None
# 23                    None                  None
# 24                    None                  None
# 25                    None                  None
# 26                    None                  None
# 27                    None                  None
# 28                    None                  None
# 29                    None                  None
# 30                    None                  None
# 31                    None                  None
# 32                    None                  None
# 33                    None                  None
# 34                    None                  None
# 35                    None                  None
# 36                    None                  None
# 37                    None                  None
# 38                    None                  None
# 39                    None                  None
# 40                    None                  None

# %%
contentParagraphsDF['source-paragraph-number'] = [None] * len(contentParagraphsDF['paragraph-text'])
contentParagraphsDF['source-paragraph-text'] = [None] * len(contentParagraphsDF['paragraph-text'])

def getTextFromWikiPage(targetURL, sourceParNum, sourceText):
    parsDict = {'source' : [], 'paragraph-number' : [], 'paragraph-text' : [], 'source-paragraph-number' : [],  'source-paragraph-text' : []}
    r = requests.get(targetURL)
    soup = bs4.BeautifulSoup(r.text, 'html.parser')
    for parNum, pTag in enumerate(soup.body.findAll('p')):
        parsDict['paragraph-text'].append(re.sub(r'\[\d+\]', '', pTag.text))
        parsDict['paragraph-number'].append(parNum)
        parsDict['source'].append(targetURL)
        parsDict['source-paragraph-number'].append(sourceParNum)
        parsDict['source-paragraph-text'].append(sourceText)
    return pandas.DataFrame(parsDict)

# %%
for urlTuple in otherPAgeURLS[:3]:
    contentParagraphsDF = contentParagraphsDF.append(getTextFromWikiPage(*urlTuple),ignore_index=True)
contentParagraphsDF
# Out:
#      paragraph-number                                     paragraph-text  \
# 0                   0  Historically and presently, in many parts of t...
# 1                   1
# 2                   2
# 3                   3  In 1540, Henry VIII of England granted the cha...
# 4                   4  At the beginning of the twenty-first century i...
# 5                   5  However, the practice of medicine remains disp...
# 6                   6  Moreover, there are skews within the medical p...
# 7                   7  Women continue to dominate in nursing. In 2000...
# 8                   8  Biomedical research and academic medical profe...
# 9                   9  The glass ceiling is used as a metaphor to con...
# 10                 10  One study surveyed physician mothers and their...
# 11                 11  According to this study, one third of physicia...
# 12                 12  This article provided an overview on the histo...
# 13                 13  In an article titled "I'm too used to it”: A l...
# 14                 14  Specifically, this article described how power...
# 15                 15  On the topic of power dynamics, another study ...
# 16                 16  Another study describes sexual harassment as a...
# 17                 17  Women have successfully provided the world wit...
# 18                 18  Helen Brooke Taussig: The First Female Preside...
# 19                 19  Helen Brooke Taussig was born on May 24th, 189...
# 20                 20  Helen Flanders Dunbar: The "Mother" of Holisti...
# 21                 21  Helen Flanders Dunbar was born in Chicago on M...
# 22                 22  As per the documentary “A Midwife’s Tale”, his...
# 23                 23  A shift from women midwifery to male obstetric...
# 24                 24  The involvement of women in the field of medic...
# 25                 25  During the Middle Ages, convents were an impor...
# 26                 26  Women in the Middle Ages participated in many ...
# 27                 27  Dorotea Bucca was another distinguished Italia...
# 28                 28  For the medieval Islamic world, little specifi...
# 29                 29  Traditional Chinese medicine based on the use ...
# ..                ...                                                ...
# 721                14  Studies have also pointed to the need for incr...
# 722                15  Workforce and health care experts anticipate t...
# 723                16  In the US, a larger proportion of the allied h...
# 724                17  In the United Kingdom there are 12 distinct pr...
# 725                18  Advancements in medical technology also allow ...
# 726                19  In developing countries, many national human r...
# 727                20  With this growing demand for ambulatory health...
# 728                 0  Medical education is education related to the ...
# 729                 1  Medical education and training varies consider...
# 730                 2
# 731                 3
# 732                 4  Entry-level medical education programs are ter...
# 733                 5  In general, initial training is taken at medic...
# 734                 6  There has been a proliferation of programmes t...
# 735                 7  Following completion of entry-level training, ...
# 736                 8  Further training in a particular field of medi...
# 737                 9  Education theory itself is becoming an integra...
# 738                10  In most countries, continuing medical educatio...
# 739                11  It is becoming more and more common for medica...
# 740                12  Research areas into online medical education i...
# 741                13  At present, in the United Kingdom, a typical m...
# 742                14  In the US and Canada, a potential medical stud...
# 743                15  In Australia, there are two pathways to a medi...
# 744                16                                               See:
# 745                17  As medical professional stakeholders in the fi...
# 746                18  There is a growing call for health professiona...
# 747                19  One 2010 survey of U.S. medical school deans o...
# 748                20  In order to truly integrate health policy matt...
# 749                21  However limitations to implementing these heal...
# 750                22  Lastly, more national support and research wil...
#
#                                                 source  \
# 0      https://en.wikipedia.org/wiki/Women_in_medicine
# 1      https://en.wikipedia.org/wiki/Women_in_medicine
# 2      https://en.wikipedia.org/wiki/Women_in_medicine
# 3      https://en.wikipedia.org/wiki/Women_in_medicine
# 4      https://en.wikipedia.org/wiki/Women_in_medicine
# 5      https://en.wikipedia.org/wiki/Women_in_medicine
# 6      https://en.wikipedia.org/wiki/Women_in_medicine
# 7      https://en.wikipedia.org/wiki/Women_in_medicine
# 8      https://en.wikipedia.org/wiki/Women_in_medicine
# 9      https://en.wikipedia.org/wiki/Women_in_medicine
# 10     https://en.wikipedia.org/wiki/Women_in_medicine
# 11     https://en.wikipedia.org/wiki/Women_in_medicine
# 12     https://en.wikipedia.org/wiki/Women_in_medicine
# 13     https://en.wikipedia.org/wiki/Women_in_medicine
# 14     https://en.wikipedia.org/wiki/Women_in_medicine
# 15     https://en.wikipedia.org/wiki/Women_in_medicine
# 16     https://en.wikipedia.org/wiki/Women_in_medicine
# 17     https://en.wikipedia.org/wiki/Women_in_medicine
# 18     https://en.wikipedia.org/wiki/Women_in_medicine
# 19     https://en.wikipedia.org/wiki/Women_in_medicine
# 20     https://en.wikipedia.org/wiki/Women_in_medicine
# 21     https://en.wikipedia.org/wiki/Women_in_medicine
# 22     https://en.wikipedia.org/wiki/Women_in_medicine
# 23     https://en.wikipedia.org/wiki/Women_in_medicine
# 24     https://en.wikipedia.org/wiki/Women_in_medicine
# 25     https://en.wikipedia.org/wiki/Women_in_medicine
# 26     https://en.wikipedia.org/wiki/Women_in_medicine
# 27     https://en.wikipedia.org/wiki/Women_in_medicine
# 28     https://en.wikipedia.org/wiki/Women_in_medicine
# 29     https://en.wikipedia.org/wiki/Women_in_medicine
# ..                                                 ...
# 721  https://en.wikipedia.org/wiki/Allied_health_pr...
# 722  https://en.wikipedia.org/wiki/Allied_health_pr...
# 723  https://en.wikipedia.org/wiki/Allied_health_pr...
# 724  https://en.wikipedia.org/wiki/Allied_health_pr...
# 725  https://en.wikipedia.org/wiki/Allied_health_pr...
# 726  https://en.wikipedia.org/wiki/Allied_health_pr...
# 727  https://en.wikipedia.org/wiki/Allied_health_pr...
# 728    https://en.wikipedia.org/wiki/Medical_education
# 729    https://en.wikipedia.org/wiki/Medical_education
# 730    https://en.wikipedia.org/wiki/Medical_education
# 731    https://en.wikipedia.org/wiki/Medical_education
# 732    https://en.wikipedia.org/wiki/Medical_education
# 733    https://en.wikipedia.org/wiki/Medical_education
# 734    https://en.wikipedia.org/wiki/Medical_education
# 735    https://en.wikipedia.org/wiki/Medical_education
# 736    https://en.wikipedia.org/wiki/Medical_education
# 737    https://en.wikipedia.org/wiki/Medical_education
# 738    https://en.wikipedia.org/wiki/Medical_education
# 739    https://en.wikipedia.org/wiki/Medical_education
# 740    https://en.wikipedia.org/wiki/Medical_education
# 741    https://en.wikipedia.org/wiki/Medical_education
# 742    https://en.wikipedia.org/wiki/Medical_education
# 743    https://en.wikipedia.org/wiki/Medical_education
# 744    https://en.wikipedia.org/wiki/Medical_education
# 745    https://en.wikipedia.org/wiki/Medical_education
# 746    https://en.wikipedia.org/wiki/Medical_education
# 747    https://en.wikipedia.org/wiki/Medical_education
# 748    https://en.wikipedia.org/wiki/Medical_education
# 749    https://en.wikipedia.org/wiki/Medical_education
# 750    https://en.wikipedia.org/wiki/Medical_education
#
#     source-paragraph-number        source-paragraph-text
# 0                      None                         None
# 1                      None                         None
# 2                      None                         None
# 3                      None                         None
# 4                      None                         None
# 5                      None                         None
# 6                      None                         None
# 7                      None                         None
# 8                      None                         None
# 9                      None                         None
# 10                     None                         None
# 11                     None                         None
# 12                     None                         None
# 13                     None                         None
# 14                     None                         None
# 15                     None                         None
# 16                     None                         None
# 17                     None                         None
# 18                     None                         None
# 19                     None                         None
# 20                     None                         None
# 21                     None                         None
# 22                     None                         None
# 23                     None                         None
# 24                     None                         None
# 25                     None                         None
# 26                     None                         None
# 27                     None                         None
# 28                     None                         None
# 29                     None                         None
# ..                      ...                          ...
# 721                       0  allied health professionals
# 722                       0  allied health professionals
# 723                       0  allied health professionals
# 724                       0  allied health professionals
# 725                       0  allied health professionals
# 726                       0  allied health professionals
# 727                       0  allied health professionals
# 728                       0            medical education
# 729                       0            medical education
# 730                       0            medical education
# 731                       0            medical education
# 732                       0            medical education
# 733                       0            medical education
# 734                       0            medical education
# 735                       0            medical education
# 736                       0            medical education
# 737                       0            medical education
# 738                       0            medical education
# 739                       0            medical education
# 740                       0            medical education
# 741                       0            medical education
# 742                       0            medical education
# 743                       0            medical education
# 744                       0            medical education
# 745                       0            medical education
# 746                       0            medical education
# 747                       0            medical education
# 748                       0            medical education
# 749                       0            medical education
# 750                       0            medical education
#
# [751 rows x 5 columns]
